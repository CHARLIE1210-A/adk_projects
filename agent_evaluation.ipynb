# %% [markdown]
# # Evaluation Criteria

# %% [markdown]
# This Colab notebook demonstrates how you can evaluate/test your Agents using various criteria using CLI. It covers following criteria:
#
#   *   `tool_trajectory_avg_score`: Compares agent's tool calls with expected trajectory.
#   *   `response_match_score`: Evaluates final response similarity using Rouge-1.
#   *   `final_response_match_v2`: Assesses semantic equivalence of responses using an LLM judge.
#   *   `rubric_based_final_response_quality_v1`: Evaluates response quality against user-defined rubrics with an LLM judge.
#   *   `rubric_based_tool_use_quality_v1`: Assesses tool usage quality against user-defined rubrics with an LLM judge.
#   *   `hallucinations_v1`: Checks for false, contradictory, or unsupported claims in agent responses.
#   *   `safety_v1`: Evaluates the harmlessness of agent responses using Vertex AI General AI Eval SDK.

# %% [markdown]
# ## Evaluation Criteria

# %% [markdown]
# ### Criterion - `tool_trajectory_avg_score`
#
# This criterion compares the tool call trajectory produced by the agent with an
# expected trajectory and computes an average score based on exact match.
#
# #### Details
#
# For each invocation that is being evaluated, this criterion compares the list of
# tool calls produced by the agent against the list of expected tool calls. The
# comparison is done by performing an exact match on the tool name and tool
# arguments for each tool call in the list. If all tool calls in an invocation
# match exactly in content and order, a score of 1.0 is awarded for that
# invocation, otherwise the score is 0.0. The final value is the average of these
# scores across all invocations in the eval case.
#
# #### Output And How To Interpret
#
# The output is a score between 0.0 and 1.0, where 1.0 indicates a perfect match
# between actual and expected tool trajectories for all invocations, and 0.0
# indicates a complete mismatch for all invocations. Higher scores are better. A
# score below 1.0 means that for at least one invocation, the agent's tool call
# trajectory deviated from the expected one.
#
# More details can be found [here](https://google.github.io/adk-docs/evaluate/criteria/#tool_trajectory_avg_score).
#
# Takes about ~30 seconds to run the cell below.

# %%
eval_config = """
{
  "criteria": {
    "tool_trajectory_avg_score": 1.0
  }
}
"""

with open("./notion_mcp_agent/eval_config.json", "w") as f:
    f.write(eval_config)

# %%
# !adk eval ./notion_mcp_agent --config_file_path ./notion_mcp_agent/eval_config.json ./notion_mcp_agent/evalset604380.evalset.json --print_detailed_results --log_level=CRITICAL
# Out:
# Using evaluation criteria: criteria={'tool_trajectory_avg_score': 1.0, 'response_match_score': 0.8} user_simulator_config=None
# *********************************************************************
# Eval Run Summary
# ../notion_mcp_agent/evalset1d0118:
#   Tests passed: 0
#   Tests failed: 1
# ********************************************************************
# Eval Set Id: ../notion_mcp_agent/evalset1d0118
# Eval Id: caseedb6bf
# Overall Eval Status: FAILED
# ---------------------------------------------------------------------
# Metric: tool_trajectory_avg_score, Status: FAILED, Score: 0.6, Threshold: 1.0
# ---------------------------------------------------------------------
# Metric: response_match_score, Status: FAILED, Score: 0.2030398835150601, Threshold: 0.8
# ---------------------------------------------------------------------
# Invocation Details:
# +----+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+-----------------------------+------------------------+
# |    | prompt                    | expected_response         | actual_response           | expected_tool_calls       | actual_tool_calls         | tool_trajectory_avg_score   | response_match_score   |
# +====+===========================+===========================+===========================+===========================+===========================+=============================+========================+
# |  0 | what tools do you have    | I have tools to interact  | I can use the following   |                           |                           | Status: PASSED, Score:      | Status: FAILED, Score: |
# |    | and what you can do       | with Notion. I can:  *    | tools:  **Notion MCP      |                           |                           | 1.0                         | 0.6692015209125476     |
# |    |                           | **Search**: Search for    | Integration:**  *         |                           |                           |                             |                        |
# |    |                           | pages and databases by    | **Users:**     * Retrieve |                           |                           |                             |                        |
# |    |                           | title. *   **Pages**: *   | a user by ID.     *       |                           |                           |                             |                        |
# |    |                           | Retrieve a page's content | List all users.     *     |                           |                           |                             |                        |
# |    |                           | and properties.     *     | Retrieve your token's bot |                           |                           |                             |                        |
# |    |                           | Create a new page. *      | user. *   **Databases:**  |                           |                           |                             |                        |
# |    |                           | Update a page's           | *   Query a database.     |                           |                           |                             |                        |
# |    |                           | properties. * **Blocks**: | *   Create a database. *  |                           |                           |                             |                        |
# |    |                           | *   Retrieve a block's    | Update a database.     *  |                           |                           |                             |                        |
# |    |                           | content.     *   Append   | Retrieve a database. *    |                           |                           |                             |                        |
# |    |                           | new blocks as children to | **Search:**     * Search  |                           |                           |                             |                        |
# |    |                           | an existing block (or     | by title. *   **Blocks:** |                           |                           |                             |                        |
# |    |                           | page). *   Update a       | * Retrieve block          |                           |                           |                             |                        |
# |    |                           | block's content (text and | children.     *   Append  |                           |                           |                             |                        |
# |    |                           | to-do checked status).    | block children.     *     |                           |                           |                             |                        |
# |    |                           | * Delete/archive a block. | Retrieve a block.     *   |                           |                           |                             |                        |
# |    |                           | * **Databases**:     *    | Update a block.     *     |                           |                           |                             |                        |
# |    |                           | Query a database to       | Delete a block. *         |                           |                           |                             |                        |
# |    |                           | retrieve pages based on   | **Pages:**     * Retrieve |                           |                           |                             |                        |
# |    |                           | filters and sorts.     *  | a page.     *   Update    |                           |                           |                             |                        |
# |    |                           | Retrieve a database's     | page properties.     *    |                           |                           |                             |                        |
# |    |                           | schema and properties.    | Create a page.     *      |                           |                           |                             |                        |
# |    |                           | *   Create a new          | Retrieve a page property  |                           |                           |                             |                        |
# |    |                           | database.     *   Update  | item. * **Comments:**     |                           |                           |                             |                        |
# |    |                           | a database's title or     | *   Retrieve comments. *  |                           |                           |                             |                        |
# |    |                           | description. *            | Create a comment.  In     |                           |                           |                             |                        |
# |    |                           | **Comments**:     *       | summary, I can perform    |                           |                           |                             |                        |
# |    |                           | Retrieve comments on a    | various operations within |                           |                           |                             |                        |
# |    |                           | block or page.     *      | Notion such as reading,   |                           |                           |                             |                        |
# |    |                           | Create new comments on a  | writing, searching, and   |                           |                           |                             |                        |
# |    |                           | page. *   **Users**:      | summarizing content from  |                           |                           |                             |                        |
# |    |                           | * Retrieve a specific     | pages and databases, as   |                           |                           |                             |                        |
# |    |                           | user.     *   List all    | well as managing users,   |                           |                           |                             |                        |
# |    |                           | users in the workspace.   | blocks, and comments.     |                           |                           |                             |                        |
# |    |                           | * Retrieve information    |                           |                           |                           |                             |                        |
# |    |                           | about the bot user        |                           |                           |                           |                             |                        |
# |    |                           | associated with the       |                           |                           |                           |                             |                        |
# |    |                           | integration. * **Page     |                           |                           |                           |                             |                        |
# |    |                           | Properties**:     *       |                           |                           |                           |                             |                        |
# |    |                           | Retrieve a specific       |                           |                           |                           |                             |                        |
# |    |                           | property item from a      |                           |                           |                           |                             |                        |
# |    |                           | page.  In short, I can    |                           |                           |                           |                             |                        |
# |    |                           | help you read, write, and |                           |                           |                           |                             |                        |
# |    |                           | manage content within     |                           |                           |                           |                             |                        |
# |    |                           | your Notion workspace!    |                           |                           |                           |                             |                        |
# +----+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+-----------------------------+------------------------+
# |  1 | can you list all pages    |                           | I can only list pages by  |                           |                           | Status: PASSED, Score:      | Status: FAILED, Score: |
# |    |                           |                           | searching for titles. Is  |                           |                           | 1.0                         | 0.0                    |
# |    |                           |                           | there a specific title or |                           |                           |                             |                        |
# |    |                           |                           | keyword you are looking   |                           |                           |                             |                        |
# |    |                           |                           | for?                      |                           |                           |                             |                        |
# +----+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+-----------------------------+------------------------+
# |  2 | list all the pages        | I found the following     | I can only list pages by  | id='adk-452f1924-d35d-459 |                           | Status: FAILED, Score:      | Status: FAILED, Score: |
# |    |                           | pages:  * **Quick Note**  | searching for titles or   | 4-bd52- 7697d0650169'     |                           | 0.0                         | 0.03813559322033898    |
# |    |                           | (ID: `19f3b3e1-4592-4445- | by filtering. Please      | args={'filter':           |                           |                             |                        |
# |    |                           | a280-e4f2b9db98b1`) *     | provide a title or a      | {'property': 'object',    |                           |                             |                        |
# |    |                           | (Untitled Page) (ID: `223 | keyword if you want to    | 'value': 'page'}}         |                           |                             |                        |
# |    |                           | 85596-7db8-802c-9708-f044 | search for specific       | name='API-post-search'    |                           |                             |                        |
# |    |                           | f02eb4b0`) *   (Untitled  | pages.                    | partial_args=None         |                           |                             |                        |
# |    |                           | Page) (ID: `28685596-7db8 |                           | will_continue=None        |                           |                             |                        |
# |    |                           | -8016-b55b-e5096a05385a`) |                           |                           |                           |                             |                        |
# |    |                           | *   (Untitled Page) (ID:  |                           |                           |                           |                             |                        |
# |    |                           | `28685596-7db8-8069-b1a2- |                           |                           |                           |                             |                        |
# |    |                           | c863611aa91e`) *          |                           |                           |                           |                             |                        |
# |    |                           | (Untitled Page) (ID: `284 |                           |                           |                           |                             |                        |
# |    |                           | 85596-7db8-803b-82fd-f297 |                           |                           |                           |                             |                        |
# |    |                           | 90f565b3`) *   (Untitled  |                           |                           |                           |                             |                        |
# |    |                           | Page) (ID: `28485596-7db8 |                           |                           |                           |                             |                        |
# |    |                           | -80fe-a064-dce29b2901dd`) |                           |                           |                           |                             |                        |
# |    |                           | *   **Nexus** (ID:        |                           |                           |                           |                             |                        |
# |    |                           | `27985596-7db8-807e-a6ec- |                           |                           |                           |                             |                        |
# |    |                           | eb7dfe0b76ea`) *          |                           |                           |                           |                             |                        |
# |    |                           | **Taken** (ID: `27285596- |                           |                           |                           |                             |                        |
# |    |                           | 7db8-8024-b71d-f18a43b120 |                           |                           |                           |                             |                        |
# |    |                           | 32`) *   **Caption** (ID: |                           |                           |                           |                             |                        |
# |    |                           | `26585596-7db8-80b7-8f91- |                           |                           |                           |                             |                        |
# |    |                           | d6c48de8ebf6`) *          |                           |                           |                           |                             |                        |
# |    |                           | **Developer Message**     |                           |                           |                           |                             |                        |
# |    |                           | (ID: `25e85596-7db8-8022- |                           |                           |                           |                             |                        |
# |    |                           | 9664-dff318f4f6df`) *     |                           |                           |                           |                             |                        |
# |    |                           | **Link** (ID: `23c85596-7 |                           |                           |                           |                             |                        |
# |    |                           | db8-8041-9c52-dbbaafad54b |                           |                           |                           |                             |                        |
# |    |                           | b`) *   **Startup         |                           |                           |                           |                             |                        |
# |    |                           | Companies** (ID: `23a8559 |                           |                           |                           |                             |                        |
# |    |                           | 6-7db8-80cd-b591-e950411d |                           |                           |                           |                             |                        |
# |    |                           | 6d9e`) *   **Email** (ID: |                           |                           |                           |                             |                        |
# |    |                           | `23885596-7db8-80b9-b22a- |                           |                           |                           |                             |                        |
# |    |                           | dbb0d6481fa4`) *   **Cold |                           |                           |                           |                             |                        |
# |    |                           | Message** (ID: `22285596- |                           |                           |                           |                             |                        |
# |    |                           | 7db8-80c9-a53e-cbe5176851 |                           |                           |                           |                             |                        |
# |    |                           | 72`) *   (Untitled Page)  |                           |                           |                           |                             |                        |
# |    |                           | (ID: `22285596-7db8-80c9- |                           |                           |                           |                             |                        |
# |    |                           | b283-dd023ad20286`) *     |                           |                           |                           |                             |                        |
# |    |                           | **Poetry / Shayari** (ID: |                           |                           |                           |                             |                        |
# |    |                           | `1d285596-7db8-809f-b512- |                           |                           |                           |                             |                        |
# |    |                           | f3da0f0a0ec4`) *          |                           |                           |                           |                             |                        |
# |    |                           | **Companies** (ID: `1d985 |                           |                           |                           |                             |                        |
# |    |                           | 596-7db8-80b7-acaa-d09f29 |                           |                           |                           |                             |                        |
# |    |                           | 4f1f99`) *   **Bring      |                           |                           |                           |                             |                        |
# |    |                           | prasad tomorrow** (ID: `0 |                           |                           |                           |                             |                        |
# |    |                           | 083f09b-5943-40ab-a575-a6 |                           |                           |                           |                             |                        |
# |    |                           | 5adc9f0ea2`) *   **Build  |                           |                           |                           |                             |                        |
# |    |                           | clone project - piyush    |                           |                           |                           |                             |                        |
# |    |                           | garg** (ID:               |                           |                           |                           |                             |                        |
# |    |                           | `ba019b2e-b2f8-40fc-      |                           |                           |                           |                             |                        |
# |    |                           | ad1e-e28a979df334`) *     |                           |                           |                           |                             |                        |
# |    |                           | **find beginner level     |                           |                           |                           |                             |                        |
# |    |                           | frontend opensource       |                           |                           |                           |                             |                        |
# |    |                           | project** (ID: `7eafa2db- |                           |                           |                           |                             |                        |
# |    |                           | d7e9-4948-9107-d99c6c5866 |                           |                           |                           |                             |                        |
# |    |                           | 6b`) *   **find fullstack |                           |                           |                           |                             |                        |
# |    |                           | flutter project** (ID: `0 |                           |                           |                           |                             |                        |
# |    |                           | 5c0f370-187a-4822-acdc-f1 |                           |                           |                           |                             |                        |
# |    |                           | 40c557a9cb`) *   **know   |                           |                           |                           |                             |                        |
# |    |                           | about noSQL basis &       |                           |                           |                           |                             |                        |
# |    |                           | firestore** (ID: `cc3b59f |                           |                           |                           |                             |                        |
# |    |                           | e-e8b7-41c8-a4c6-dcf3ae1f |                           |                           |                           |                             |                        |
# |    |                           | 726b`) *   **Usefull      |                           |                           |                           |                             |                        |
# |    |                           | Software** (ID: `27a611f1 |                           |                           |                           |                             |                        |
# |    |                           | -63c7-440d-920d-de13f176c |                           |                           |                           |                             |                        |
# |    |                           | dcd`) *   **Quantum       |                           |                           |                           |                             |                        |
# |    |                           | Computing** (ID: `c532449 |                           |                           |                           |                             |                        |
# |    |                           | 3-e5d0-4f68-bcb1-b923f5ee |                           |                           |                           |                             |                        |
# |    |                           | 1c01`) *   **Task** (ID:  |                           |                           |                           |                             |                        |
# |    |                           | `38bb2abf-b064-43c1-84e0- |                           |                           |                           |                             |                        |
# |    |                           | a6ae24eec430`) *          |                           |                           |                           |                             |                        |
# |    |                           | (Untitled Page) (ID: `e67 |                           |                           |                           |                             |                        |
# |    |                           | ceb1a-8bf9-4ce7-a09a-a4e1 |                           |                           |                           |                             |                        |
# |    |                           | 759ef8ab`) *   **Getting  |                           |                           |                           |                             |                        |
# |    |                           | Started on Mobile** (ID:  |                           |                           |                           |                             |                        |
# |    |                           | `3ea64aa0-6e69-4008-a553- |                           |                           |                           |                             |                        |
# |    |                           | 8ba3b377c6b5`) *          |                           |                           |                           |                             |                        |
# |    |                           | **Example sub page** (ID: |                           |                           |                           |                             |                        |
# |    |                           | `244501a5-02f4-4a37-9358- |                           |                           |                           |                             |                        |
# |    |                           | 74b34b09fce2`) *   **Just |                           |                           |                           |                             |                        |
# |    |                           | another day** (ID: `10445 |                           |                           |                           |                             |                        |
# |    |                           | be7-f825-450c-8159-8f68bd |                           |                           |                           |                             |                        |
# |    |                           | c51fb2`) *   **Hawaii     |                           |                           |                           |                             |                        |
# |    |                           | Vacation** (ID: `124ce78d |                           |                           |                           |                             |                        |
# |    |                           | -5875-423a-a819-3471ec15f |                           |                           |                           |                             |                        |
# |    |                           | 06d`) *   **Daily         |                           |                           |                           |                             |                        |
# |    |                           | reflection** (ID: `2f5ee1 |                           |                           |                           |                             |                        |
# |    |                           | f9-b129-41bf-9234-e512820 |                           |                           |                           |                             |                        |
# |    |                           | 2ac60`) *   **Job Search  |                           |                           |                           |                             |                        |
# |    |                           | - September** (ID: `77691 |                           |                           |                           |                             |                        |
# |    |                           | 7fa-784d-49cb-a24d-315185 |                           |                           |                           |                             |                        |
# |    |                           | a5939b`) *   **Daily      |                           |                           |                           |                             |                        |
# |    |                           | entry** (ID: `8ffb1c4e-e6 |                           |                           |                           |                             |                        |
# |    |                           | a9-41b3-baff-b37589f7d159 |                           |                           |                           |                             |                        |
# |    |                           | `) *   **So much to be    |                           |                           |                           |                             |                        |
# |    |                           | grateful for** (ID:       |                           |                           |                           |                             |                        |
# |    |                           | `9441ffb0-f395-4920-93cb- |                           |                           |                           |                             |                        |
# |    |                           | af5c790345b0`) *   **28th |                           |                           |                           |                             |                        |
# |    |                           | Birthday** (ID: `bb462502 |                           |                           |                           |                             |                        |
# |    |                           | -72af-4b98-a6c9-985715e70 |                           |                           |                           |                             |                        |
# |    |                           | 125`) *   **Date with     |                           |                           |                           |                             |                        |
# |    |                           | Stewart** (ID: `e9e3761d- |                           |                           |                           |                             |                        |
# |    |                           | 408c-48df-805a-18bb7577a9 |                           |                           |                           |                             |                        |
# |    |                           | 44`) *   **Sub Page**     |                           |                           |                           |                             |                        |
# |    |                           | (ID: `48af2530-3506-4f0e- |                           |                           |                           |                             |                        |
# |    |                           | b34e-6aaebd0a1f96`) *     |                           |                           |                           |                             |                        |
# |    |                           | **New Task** (ID: `1e21ba |                           |                           |                           |                             |                        |
# |    |                           | 86-0297-4674-8ef6-41e1e97 |                           |                           |                           |                             |                        |
# |    |                           | 2f4cf`) *   (Untitled     |                           |                           |                           |                             |                        |
# |    |                           | Page) (ID: `6fd7c445-e1e6 |                           |                           |                           |                             |                        |
# |    |                           | -46d9-b0e3-aa017a6498ac`) |                           |                           |                           |                             |                        |
# |    |                           | *   **Take Fig on a       |                           |                           |                           |                             |                        |
# |    |                           | walk** (ID: `93b733f6-c6e |                           |                           |                           |                             |                        |
# |    |                           | 3-470b-9262-ea2feb02f544` |                           |                           |                           |                             |                        |
# |    |                           | ) *   **New book** (ID:   |                           |                           |                           |                             |                        |
# |    |                           | `29dd02ee- ebf2-46b8-876d |                           |                           |                           |                             |                        |
# |    |                           | -e851cdd99a19`) *         |                           |                           |                           |                             |                        |
# |    |                           | **Sapiens: A Brief        |                           |                           |                           |                             |                        |
# |    |                           | History of Humankind**    |                           |                           |                           |                             |                        |
# |    |                           | (ID: `66c9f458-4f69-468d- |                           |                           |                           |                             |                        |
# |    |                           | 84b4-ed305ffaad7c`) *     |                           |                           |                           |                             |                        |
# |    |                           | **New TV series** (ID: `a |                           |                           |                           |                             |                        |
# |    |                           | da1e67a-5da6-4602-b8a7-28 |                           |                           |                           |                             |                        |
# |    |                           | 443d22df13`) *   **Brave  |                           |                           |                           |                             |                        |
# |    |                           | New World** (ID: `b80e893 |                           |                           |                           |                             |                        |
# |    |                           | 9-1e0f-4d7c-bc17-53b51cac |                           |                           |                           |                             |                        |
# |    |                           | c5d8`) *   **Crime and    |                           |                           |                           |                             |                        |
# |    |                           | Punishment** (ID: `edadcb |                           |                           |                           |                             |                        |
# |    |                           | ab-d7a9-4f2d-a712-e15e200 |                           |                           |                           |                             |                        |
# |    |                           | 919c8`) *   **Who Will    |                           |                           |                           |                             |                        |
# |    |                           | Teach Silicon Valley to   |                           |                           |                           |                             |                        |
# |    |                           | Be Ethical?** (ID: `ee1b3 |                           |                           |                           |                             |                        |
# |    |                           | 2ca-24b5-47c8-b269-99bf05 |                           |                           |                           |                             |                        |
# |    |                           | bd9f13`) *   **New        |                           |                           |                           |                             |                        |
# |    |                           | article** (ID: `f7a9eff9- |                           |                           |                           |                             |                        |
# |    |                           | e0ac-4258-94a4-eddcbd3487 |                           |                           |                           |                             |                        |
# |    |                           | a7`) *   **Netflix:       |                           |                           |                           |                             |                        |
# |    |                           | explained** (ID: `f977592 |                           |                           |                           |                             |                        |
# |    |                           | e-3ac9-469c-b2fc-71e11cd8 |                           |                           |                           |                             |                        |
# |    |                           | 3101`) *   **Movie List** |                           |                           |                           |                             |                        |
# |    |                           | (ID: `63b21d7f-7820-4686- |                           |                           |                           |                             |                        |
# |    |                           | 9ddf-d3800bc08544`) *     |                           |                           |                           |                             |                        |
# |    |                           | **Yearly Goals** (ID: `69 |                           |                           |                           |                             |                        |
# |    |                           | da025a-e24b-4f93-b772-d1c |                           |                           |                           |                             |                        |
# |    |                           | ba7af1322`) *             |                           |                           |                           |                             |                        |
# |    |                           | **Personal Home** (ID: `8 |                           |                           |                           |                             |                        |
# |    |                           | 8e516a4-7184-4124-a164-73 |                           |                           |                           |                             |                        |
# |    |                           | 8b267c35c3`)              |                           |                           |                           |                             |                        |
# +----+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+-----------------------------+------------------------+
# |  3 | can you summarize this    | The Notion page "Nexus"   | I am unable to provide a  | id='adk-a1c981b6-4202-436 | id='adk-c07a38bd-e109-4c6 | Status: FAILED, Score:      | Status: FAILED, Score: |
# |    | page - Nexus (ID:         | contains the following    | summary of the page       | a-85bc- 532c0e8db009'     | 0-aa9b- 0c8205495ae9'     | 0.0                         | 0.27692307692307694    |
# |    | 27985596-7db8-807e-a6ec-  | points as of 2025-09-25:  | content as the tool only  | args={'block_id':         | args={'page_id':          |                             |                        |
# |    | eb7dfe0b76ea)             | * Integrate API KEY. *    | returns the page's        | '27985596-7db8-807e-a6ec- | '27985596-7db8-807e-a6ec- |                             |                        |
# |    |                           | Users do not need an API  | metadata, such as its ID, | eb7dfe0b76ea'} name='API- | eb7dfe0b76ea'} name='API- |                             |                        |
# |    |                           | KEY for publicly          | creation time, last       | get-block-children'       | retrieve-a-page'          |                             |                        |
# |    |                           | available agents. *   For | edited time, and title.   | partial_args=None         | partial_args=None         |                             |                        |
# |    |                           | private agents, users     | It does not return the    | will_continue=None        | will_continue=None        |                             |                        |
# |    |                           | must request access from  | actual content within the |                           |                           |                             |                        |
# |    |                           | the provider. * A method  | page.  However, I can     |                           |                           |                             |                        |
# |    |                           | should be used to store   | tell you that the page is |                           |                           |                             |                        |
# |    |                           | agent- cards to avoid     | titled "Nexus", was       |                           |                           |                             |                        |
# |    |                           | unnecessary API calls to  | created on September 25,  |                           |                           |                             |                        |
# |    |                           | fetch agent IDs. *   The  | 2025, and last edited on  |                           |                           |                             |                        |
# |    |                           | next step is to work on   | September 25, 2025.       |                           |                           |                             |                        |
# |    |                           | the CLI tool.             |                           |                           |                           |                             |                        |
# +----+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+-----------------------------+------------------------+
# |  4 | tell me what is given in  | Here's the content of the | The page "Poetry /        | id='adk-9bbab47b-3a52-488 | id='adk-e0f8e3f6-7747-4a4 | Status: PASSED, Score:      | Status: FAILED, Score: |
# |    | these page - Poetry /     | "Poetry / Shayari" page:  | Shayari" contains several | b-ae47- 5c829ce1820c'     | 6-a269- 0a171955c527'     | 1.0                         | 0.030939226519337015   |
# |    | Shayari (ID: 1d285596-7db | Jhuto ke beech mei mai    | paragraphs of poetic text | args={'block_id': '1d2855 | args={'block_id': '1d2855 |                             |                        |
# |    | 8-809f-b512-f3da0f0a0ec4) | sach bol betha wah namak  | in Hindi/Urdu. Here's a   | 96-7db8-809f-b512-f3da0f0 | 96-7db8-809f-b512-f3da0f0 |                             |                        |
# |    |                           | ka saher tha aur mai apne | summary of the content:   | a0ec4'} name='API-get-    | a0ec4'} name='API-get-    |                             |                        |
# |    |                           | sakhm khol betha   Fasle  | The page contains a       | block-children'           | block-children'           |                             |                        |
# |    |                           | ese bhi honge socha na    | collection of short poems | partial_args=None         | partial_args=None         |                             |                        |
# ...
# |    |                           | ladka tha main... Jin     | own eyes. *   **Nostalgia |                           |                           |                             |                        |
# |    |                           | dino ek mele se guzarta   | and Loss of Innocence:**  |                           |                           |                             |                        |
# |    |                           | tha, Muskaan thi aankhon  | A longer poem describes a |                           |                           |                             |                        |
# |    |                           | mein, Jee machlata tha    | young, innocent boy at a  |                           |                           |                             |                        |
# |    |                           | har cheez par... Par      | fair who desired          |                           |                           |                             |                        |
# |    |                           | mol... kabhi na de saka.  | everything but couldn't   |                           |                           |                             |                        |
# |    |                           | Aaj bhi mela laga hai,    | afford anything. Now, as  |                           |                           |                             |                        |
# |    |                           | Ussi roshni, ussi rangin  | an adult, he can buy      |                           |                           |                             |                        |
# |    |                           | shaan ke saath. Aaj       | anything at the same      |                           |                           |                             |                        |
# |    |                           | chahoon toh... Ek-ek      | fair, but the childlike   |                           |                           |                             |                        |
# |    |                           | dukaan kharid loon,       | enthusiasm and desire are |                           |                           |                             |                        |
# |    |                           | Chaand bhi, apni jeb mein | gone. *   **Possession    |                           |                           |                             |                        |
# |    |                           | bhar loon... Lekin... Ab  | and Secrecy:** A couplet  |                           |                           |                             |                        |
# |    |                           | jee mein woh dhadkan      | expresses a stubborn      |                           |                           |                             |                        |
# |    |                           | kahan? Woh ras bhari,     | desire to claim the       |                           |                           |                             |                        |
# |    |                           | beparwah si chahat kahan? | beloved from everyone.    |                           |                           |                             |                        |
# |    |                           | Aur main bhi... Ab woh    | Another speaks of those   |                           |                           |                             |                        |
# |    |                           | chhota sa allhad sa       | who cry in solitude, not  |                           |                           |                             |                        |
# |    |                           | ladka... Kahan?  Yea zid  | making a public spectacle |                           |                           |                             |                        |
# |    |                           | hai hamari ke tumhe chin  | of their sorrows. *       |                           |                           |                             |                        |
# |    |                           | lein sbse Gamon aur       | **Sudden Affection:** A   |                           |                           |                             |                        |
# |    |                           | zamane se takaja nahi     | verse suggests that       |                           |                           |                             |                        |
# |    |                           | karte wo ro lete hai      | sometimes someone can     |                           |                           |                             |                        |
# |    |                           | gosaye tanhai mai aksar   | become endearing in an    |                           |                           |                             |                        |
# |    |                           | hum saher ke gaaliyon mai | instant, and without any  |                           |                           |                             |                        |
# |    |                           | tamasha nahi karte  Yu    | specific reason, a        |                           |                           |                             |                        |
# |    |                           | bhi ho sakata hai ke ek   | commotion can arise in    |                           |                           |                             |                        |
# |    |                           | pal Mai koi acha lag jaye | the heart. *   **Reality  |                           |                           |                             |                        |
# |    |                           | ,baat koi bhi na ho aur   | of Love vs.               |                           |                           |                             |                        |
# |    |                           | dil mai tamasha ho jaye . | Expectations:** A poem    |                           |                           |                             |                        |
# |    |                           | Mohaabat mai jo sun rakha | discusses how love in     |                           |                           |                             |                        |
# |    |                           | tha waisa kuch nahi hota  | reality is not like what  |                           |                           |                             |                        |
# |    |                           | ke isme banda mar jata    | is heard in stories or    |                           |                           |                             |                        |
# |    |                           | hai jyada kuch nahi hota  | seen in movies, where     |                           |                           |                             |                        |
# |    |                           | ke filmo mai he sabko     | everyone finds love. It   |                           |                           |                             |                        |
# |    |                           | pyar mil jata hai akhir   | also mentions poverty     |                           |                           |                             |                        |
# |    |                           | mai .magar sach much iss  | taking away one's world,  |                           |                           |                             |                        |
# |    |                           | duniya mai esa kuch nahi  | contrasting with a        |                           |                           |                             |                        |
# |    |                           | hota .meri gurbat ne mujh | mother's belief that      |                           |                           |                             |                        |
# |    |                           | se meri duniya chin Lee   | money isn't everything. * |                           |                           |                             |                        |
# |    |                           | hafi.meri ammi to kehti   | **Unending Desire:** A    |                           |                           |                             |                        |
# |    |                           | thi ke paesa sab kuch     | couplet expresses a       |                           |                           |                             |                        |
# |    |                           | nahi hota   Hasrat hai ke | strong desire to see a    |                           |                           |                             |                        |
# |    |                           | usse jee bhar kar dekhu , | beloved to one's heart's  |                           |                           |                             |                        |
# |    |                           | Masla yeh bhi ke jee      | content, but questions if |                           |                           |                             |                        |
# |    |                           | bharega kya  Wah shone ke | the heart will ever truly |                           |                           |                             |                        |
# |    |                           | kangan pahen chuki thi    | be satisfied. *           |                           |                           |                             |                        |
# |    |                           | Jab mai chudiyaa kharidne | **Missed Opportunities    |                           |                           |                             |                        |
# |    |                           | ke kaabil hua  Kangan     | and Timeliness:** A       |                           |                           |                             |                        |
# |    |                           | teri hatho mea pahena     | poignant couplet          |                           |                           |                             |                        |
# |    |                           | achaa lage  Har dard tere | describes how a beloved   |                           |                           |                             |                        |
# |    |                           | ishq mae sahena acha lage | was already wearing gold  |                           |                           |                             |                        |
# |    |                           | Aate ho samne ban sawar   | bangles when the speaker  |                           |                           |                             |                        |
# |    |                           | ke jab bhi  Har baar meri | finally became capable of |                           |                           |                             |                        |
# |    |                           | ankhon ko tujhe dekhana   | buying bangles. *         |                           |                           |                             |                        |
# |    |                           | acha lage                 | **Admiration in Love:**   |                           |                           |                             |                        |
# |    |                           |                           | The final section         |                           |                           |                             |                        |
# |    |                           |                           | expresses that wearing    |                           |                           |                             |                        |
# |    |                           |                           | bangles in the beloved's  |                           |                           |                             |                        |
# |    |                           |                           | hands feels good,         |                           |                           |                             |                        |
# |    |                           |                           | enduring every pain for   |                           |                           |                             |                        |
# |    |                           |                           | their love feels good,    |                           |                           |                             |                        |
# |    |                           |                           | and every time they       |                           |                           |                             |                        |
# |    |                           |                           | appear adorned, seeing    |                           |                           |                             |                        |
# |    |                           |                           | them fills the speaker's  |                           |                           |                             |                        |
# |    |                           |                           | eyes with joy.            |                           |                           |                             |                        |
# +----+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+-----------------------------+------------------------+
# C:\Users\91789\Desktop\Project\ADK_Project\.venv\Lib\site-packages\google\adk\evaluation\metric_evaluator_registry.py:90: UserWarning: [EXPERIMENTAL] MetricEvaluatorRegistry: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   metric_evaluator_registry = MetricEvaluatorRegistry()
# C:\Users\91789\Desktop\Project\ADK_Project\.venv\Lib\site-packages\google\adk\evaluation\local_eval_service.py:79: UserWarning: [EXPERIMENTAL] UserSimulatorProvider: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   user_simulator_provider: UserSimulatorProvider = UserSimulatorProvider(),
# C:\Users\91789\Desktop\Project\ADK_Project\.venv\Lib\site-packages\google\adk\cli\cli_tools_click.py:650: UserWarning: [EXPERIMENTAL] UserSimulatorProvider: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   user_simulator_provider = UserSimulatorProvider(
# C:\Users\91789\Desktop\Project\ADK_Project\.venv\Lib\site-packages\google\adk\cli\cli_tools_click.py:655: UserWarning: [EXPERIMENTAL] LocalEvalService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   eval_service = LocalEvalService(
# C:\Users\91789\Desktop\Project\ADK_Project\.venv\Lib\site-packages\google\adk\evaluation\user_simulator_provider.py:77: UserWarning: [EXPERIMENTAL] StaticUserSimulator: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   return StaticUserSimulator(static_conversation=eval_case.conversation)
# C:\Users\91789\Desktop\Project\ADK_Project\.venv\Lib\site-packages\google\adk\evaluation\static_user_simulator.py:39: UserWarning: [EXPERIMENTAL] UserSimulator: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__(
# C:\Users\91789\Desktop\Project\ADK_Project\.venv\Lib\site-packages\google\adk\tools\mcp_tool\mcp_tool.py:101: UserWarning: [EXPERIMENTAL] BaseAuthenticatedTool: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__(

# %% [markdown]
# ### Criterion - `response_match_score`
#
# This criterion evaluates if agent's final response matches a golden/expected
# final response using Rouge-1.
#
# #### Details
#
# To learn more, see details on
# [ROUGE-1](https://github.com/google-research/google-research/tree/master/rouge).
#
# #### Output And How To Interpret
#
# Value range for this criterion is [0,1], with values closer to 1 more desirable.
#
# More details can be found [here](https://google.github.io/adk-docs/evaluate/criteria/#response_match_score).
#
# Takes about ~30 seconds to run the cell below.

# %%
eval_config="""
{
  "criteria": {
    "response_match_score": 0.8
  }
}
"""

with open("./notion_mcp_agent/eval_config.json", "w") as f:
    f.write(eval_config)

# %%
# !adk eval ./notion_mcp_agent --config_file_path ./notion_mcp_agent/eval_config ./notion_mcp_agent/evalset1d0118 --print_detailed_results --log_level=CRITICAL

# %% [markdown]
# ### Criterion - `final_response_match_v2`
#
# This criterion evaluates if the agent's final response matches a golden/expected
# final response using LLM as a judge.
#
# #### Details
#
# This criterion uses a Large Language Model (LLM) as a judge to determine if the
# agent's final response is semantically equivalent to the provided reference
# response. It is designed to be more flexible than lexical matching metrics (like
# `response_match_score`), as it focuses on whether the agent's response contains
# the correct information, while tolerating differences in formatting, phrasing,
# or the inclusion of additional correct details.
#
# For each invocation, the criterion prompts a judge LLM to rate the agent's
# response as "valid" or "invalid" compared to the reference. This is repeated
# multiple times for robustness (configurable via `num_samples`), and a majority
# vote determines if the invocation receives a score of 1.0 (valid) or 0.0
# (invalid). The final criterion score is the fraction of invocations deemed valid
# across the entire eval case.
#
# #### Output And How To Interpret
#
# The criterion returns a score between 0.0 and 1.0. A score of 1.0 means the LLM
# judge considered the agent's final response to be valid for all invocations,
# while a score closer to 0.0 indicates that many responses were judged as invalid
# when compared to the reference responses. Higher values are better.
#
# More details can be found [here](https://google.github.io/adk-docs/evaluate/criteria/#final_response_match_v2).
#
# Takes about ~1 minute to run the cell below.

# %%
eval_config="""
{
  "criteria": {
    "final_response_match_v2": {
      "threshold": 0.8,
      "judge_model_options": {
            "judge_model": "gemini-2.5-flash",
            "num_samples": 5
      }
    }
  }
}
"""

with open("./notion_mcp_agent/eval_config.json", "w") as f:
    f.write(eval_config)

# %%
# !adk eval ../notion_mcp_agent ../notion_mcp_agent/evalset604380 --config_file_path ../notion_mcp_agent/eval_config --print_detailed_results --log_level=CRITICAL

# %% [markdown]
# ### Criterion - `rubric_based_final_response_quality_v1`
#
# This criterion assesses the quality of an agent's final response against a
# user-defined set of rubrics using LLM as a judge.
#
# #### Details
#
# This criterion provides a flexible way to evaluate response quality based on
# specific criteria that you define as rubrics. For example, you could define
# rubrics to check if a response is concise, if it correctly infers user intent,
# or if it avoids jargon.
#
# The criterion uses an LLM-as-a-judge to evaluate the agent's final response
# against each rubric, producing a `yes` (1.0) or `no` (0.0) verdict for each.
# Like other LLM-based metrics, it samples the judge model multiple times per
# invocation and uses a majority vote to determine the score for each rubric in
# that invocation. The overall score for an invocation is the average of its
# rubric scores. The final criterion score for the eval case is the average of
# these overall scores across all invocations.
#
# #### Output And How To Interpret
#
# The criterion outputs an overall score between 0.0 and 1.0, where 1.0 indicates
# that the agent's responses satisfied all rubrics across all invocations, and 0.0
# indicates that no rubrics were satisfied. The results also include detailed
# per-rubric scores for each invocation. Higher values are better.
#
# More details can be found [here](https://google.github.io/adk-docs/evaluate/criteria/#rubric_based_final_response_quality_v1).
#
# Takes about 1-2 minutes to run the cell below.

# %%
eval_config="""
{
  "criteria": {
    "rubric_based_final_response_quality_v1": {
      "threshold": 0.8,
      "judge_model_options": {
        "judge_model": "gemini-2.5-flash",
        "num_samples": 5
      },
      "rubrics": [
        {
          "rubric_id": "conciseness",
          "rubric_content": {
            "text_property": "The response from the agent is direct and to the point."
          }
        },
        {
          "rubric_id": "intent_inference",
          "rubric_content": {
            "text_property": "The response from the agent accurately infers the underlying goal from ambiguous queries."
          }
        }
      ]
    }
  }
}
"""

with open("./notion_mcp_agent/eval_config.json", "w") as f:
    f.write(eval_config)

# %%
# !adk eval ./notion_mcp_agent --config_file_path ./notion_mcp_agent/eval_config.json ./notion_mcp_agent/evalset604380.evalset.json --print_detailed_results --log_level=CRITICAL

# %% [markdown]
# ### Criterion - `hallucinations_v1`
# This criterion assesses whether a model response contains any false,
# contradictory, or unsupported claims.
#
# #### Details
#
# This criterion assesses whether a model response contains any false,
# contradictory, or unsupported claims based on context that includes developer
# instructions, user prompt, tool definitions, and tool invocations and their
# results. It uses LLM-as-a-judge and follows a two-step process:
#
# 1.  **Segmenter**: Segments the agent response into individual sentences.
# 2.  **Sentence Validator**: Evaluates each segmented sentence against the
#     provided context for grounding. Each sentence is labeled as `supported`,
#     `unsupported`, `contradictory`, `disputed` or `not_applicable`.
#
# The metric computes an Accuracy Score: the percentage of sentences that are
# `supported` or `not_applicable`. By default, only the final response is
# evaluated. If `evaluate_intermediate_nl_responses` is set to true in the
# criterion, intermediate natural language responses from agents are also
# evaluated.
#
# #### Output And How To Interpret
#
# The criterion returns a score between 0.0 and 1.0. A score of 1.0 means all
# sentences in agent's response are grounded in the context, while a score closer
# to 0.0 indicates that many sentences are false, contradictory, or unsupported.
# Higher values are better.
#
# More details can be found [here](https://google.github.io/adk-docs/evaluate/criteria/#hallucinations_v1).
#
# Takes about 1-2 minutes to run the cell below.

# %%
eval_config="""
{
  "criteria": {
    "hallucinations_v1": {
      "threshold": 0.5,
      "evaluate_intermediate_nl_responses": false
    }
  }
}
"""

with open("./notion_mcp_agent/eval_config.json", "w") as f:
    f.write(eval_config)

# %%
# !adk eval ./notion_mcp_agent --config_file_path ./notion_mcp_agent/eval_config.json ./notion_mcp_agent/evalset604380.evalset.json --print_detailed_results --log_level=CRITICAL

# %% [markdown]
# ### Criterion - `safety_v1`
#
# This criterion evaluates the safety (harmlessness) of an Agent's Response.
#
# #### Details
#
# This criterion assesses whether the agent's response contains any harmful
# content, such as hate speech, harassment, or dangerous information. Unlike other
# metrics implemented natively within ADK, `safety_v1` delegates the evaluation to
# the Vertex AI General AI Eval SDK.
#
# #### Output And How To Interpret
#
# The criterion returns a score between 0.0 and 1.0. Scores closer to 1.0 indicate
# that the response is safe, while scores closer to 0.0 indicate potential safety
# issues.
#
# More details can be found [here](https://google.github.io/adk-docs/evaluate/criteria/#safety_v1).
#
# Takes about 1-2 minutes to run the cell below.

# %%
eval_config="""
{
  "criteria": {
    "safety_v1": 0.8
  }
}
"""

with open("./notion_mcp_agent/eval_config.json", "w") as f:
    f.write(eval_config)

# %%
# !adk eval ./notion_mcp_agent --config_file_path ./notion_mcp_agent/eval_config.json ./notion_mcp_agent/evalset604380.evalset.json --print_detailed_results --log_level=CRITICAL
